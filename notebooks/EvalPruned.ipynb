# %%
import sys

sys.path.append("..")
import pickle as pkl
from dataclasses import asdict, is_dataclass

import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
from dacite import from_dict
from ipywidgets import interact

from calibration.benchmark.benchmark import calibrate, evaluate, get_camera_from_entry
from calibration.benchmark.benchmark_result import (
    BenchmarkResult,
    calc_error,
    results_into_df,
)
from calibration.feature_detector.visualization import show_boards, show_corners
from calibration.feature_refiner.refine import refine_features, refine_features_single
from calibration.feature_refiner.visualization import show_refined_corners
from calibration.projector.board import gen_checkerboard_grid
from calibration.projector.camera import Camera

# pio.renderers.default = "svg"
from calibration.projector.projector import Projector
from calibration.solver.optimization.solve import solve as solve_optimization
from calibration.solver.scaramuzza.solve import solve as solve_scaramuzza

# from calibration.solver.solve import solve

# %load_ext autoreload
# %autoreload 2

# %%
# with open("../babelcalib_results_overlay.pkl", "rb") as f:
with open("../babelcalib_results_prune_corners.pkl", "rb") as f:
    results = pkl.load(f)

results = [r for r in results if r is not None and r.features is not None]

# %%
results_ = refine_features(results)
# Out:
# Refining features:   0%|          | 0/792 [00:00<?, ?it/s]
# Process ForkProcess-12:
# Process ForkProcess-5:
# Process ForkProcess-4:
# Traceback (most recent call last):
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 103, in get
#     res = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/connection.py", line 215, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Process ForkProcess-1:
# Process ForkProcess-8:
# Process ForkProcess-11:
# Process ForkProcess-9:
# Process ForkProcess-7:
# Process ForkProcess-10:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkProcess-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkProcess-6:
# Process ForkProcess-3:
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 342, in run
#     self.terminate_broken(cause)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 490, in terminate_broken
#     work_item.future.set_exception(bpe)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/_base.py", line 559, in set_exception
#     raise InvalidStateError('{}: {!r}'.format(self._state, self))
# concurrent.futures._base.InvalidStateError: CANCELLED: <Future at 0x7f1bd3ed01d0 state=cancelled>
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/astadnik/micromamba/envs/camera_calibration/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#
# KeyboardInterrupt

# %%
mask = {i for i, r in enumerate(results_) if r is not None}

# %%
res = [results[i] for i in sorted(list(mask))]
res_ = [results_[i] for i in sorted(list(mask))]

# %%
_solvers = [("Optimization", solve_optimization)]

# %%
ents_and_feats = [(r.input, r.features) for r in res_]
solvers_args = [(f, get_camera_from_entry(e)) if f else None for e, f in ents_and_feats]
projs = calibrate(_solvers, solvers_args)
assert len(projs) == len(ents_and_feats)
return evaluate(ents_and_feats, projs)
